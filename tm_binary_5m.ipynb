# %%
import os
import pandas as pd
import numpy as np
import talib
import lightgbm as lgb
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split, KFold
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from datetime import datetime, time, timedelta

pd.set_option('display.max_columns', None)

def load_data(file_names):
    dfs = []
    for file_name in file_names:
        prefix = file_name.split('_')[1]
        df = pd.read_csv(file_name, index_col=f"{prefix}_timestamp")
        df.index = pd.to_datetime(df.index, unit="ms")
        dfs.append(df)
    return dfs

def feature_engineering(df, prefix):
    open = df[f'{prefix}_open'].values
    high = df[f'{prefix}_high'].values
    low = df[f'{prefix}_low'].values
    close = df[f'{prefix}_close'].values
    volume = df[f'{prefix}_volume'].values
    hilo = (high + low) / 2

    df[f'{prefix}_RSI_ST'] = talib.RSI(close)/close
    df[f'{prefix}_RSI_LOG'] = log_transform_feature(talib.RSI(close))
    df[f'{prefix}_MACD'], _, _ = talib.MACD(close)
    df[f'{prefix}_MACD_ST'], _, _ = talib.MACD(close)/close
    df[f'{prefix}_ATR'] = talib.ATR(high, low, close)
    df[f'{prefix}_ADX'] = talib.ADX(high, low, close, timeperiod=14)
    df[f'{prefix}_ADXR'] = talib.ADXR(high, low, close, timeperiod=14)
    
    df[f'{prefix}_SMA20'] = talib.SMA(close, timeperiod=20)
    df[f'{prefix}_SMA50'] = talib.SMA(close, timeperiod=50)
    df[f'{prefix}_SMA100'] = talib.SMA(close, timeperiod=100)
    
    df[f'{prefix}_BB_UPPER'], df[f'{prefix}_BB_MIDDLE'], df[f'{prefix}_BB_LOWER'] = talib.BBANDS(close)
    df[f'{prefix}_BBANDS_upperband'] = (df[f'{prefix}_BB_UPPER'] - hilo) / close
    df[f'{prefix}_BBANDS_middleband'] = (df[f'{prefix}_BB_MIDDLE'] - hilo) / close
    df[f'{prefix}_BBANDS_lowerband'] = (df[f'{prefix}_BB_LOWER'] - hilo) / close
    df[f'{prefix}_STOCH_K'], df[f'{prefix}_STOCH_D'] = talib.STOCH(high, low, close)/close
    df[f'{prefix}_MON'] = talib.MOM(close, timeperiod=5)
    df[f'{prefix}_OBV'] = talib.OBV(close, volume)

    df = df.fillna(method='ffill')

    return df

def log_transform_feature(X):
    X[X <= 0] = np.finfo(float).eps
    return np.log(X)

def support_resistance(df, prefix, window=20):
    high = df[f'{prefix}_high']
    low = df[f'{prefix}_low']
    close = df[f'{prefix}_close']
    df[f'{prefix}_support'] = low.rolling(window=window, min_periods=1).min()
    df[f'{prefix}_resistance'] = high.rolling(window=window, min_periods=1).max()
    return df

def price_relation(df, short_prefix, long_prefix):
    short_close = df[f'{short_prefix}_close']
    long_support = df[f'{long_prefix}_support']
    long_resistance = df[f'{long_prefix}_resistance']
    df[f'{short_prefix}_close_to_{long_prefix}_support'] = (short_close - long_support) / long_support
    df[f'{short_prefix}_close_to_{long_prefix}_resistance'] = (short_close - long_resistance) / long_resistance
    return df

def calculate_high_close_comparison(df, prefix):
    high = df[f'{prefix}_high'].values
    close = df[f'{prefix}_close'].values
    higher_high = np.zeros(len(high), dtype=int)
    higher_close = np.zeros(len(close), dtype=int)
    higher_high[1:] = high[1:] > high[:-1]
    higher_close[1:] = close[1:] > close[:-1]
    high_close_comparison = higher_high & higher_close
    return high_close_comparison

def detect_double_top_bottom(df, prefix, window=5, tolerance=0.03):
    double_top = np.zeros(len(df), dtype=int)
    double_bottom = np.zeros(len(df), dtype=int)

    close = df[f'{prefix}_close'].values
    close_ext = np.pad(close, (window, window), mode='edge')

    for i in range(window, len(df) - window):
        considered_range = close_ext[i:i + window * 2 + 1]
        max_index = np.argmax(considered_range)
        min_index = np.argmin(considered_range)

        if max_index == window:
            max_left = np.max(considered_range[:window])
            max_right = np.max(considered_range[window + 1:])
            max_avg = (max_left + max_right) / 2

            if np.abs(considered_range[window] - max_avg) / considered_range[window] <= tolerance:
                double_top[i] = 1

        if min_index == window:
            min_left = np.min(considered_range[:window])
            min_right = np.min(considered_range[window + 1:])
            min_avg = (min_left + min_right) / 2

            if np.abs(considered_range[window] - min_avg) / considered_range[window] <= tolerance:
                double_bottom[i] = 1

    return double_top, double_bottom

def create_label(df, prefix, lookbehind=1):
    df[f'{prefix}_target'] = (df[f'{prefix}_close'] > df[f'{prefix}_close'].shift(lookbehind)).astype(int)
    df = df.fillna(method='ffill')
    return df

def plot_learning_curve(evals_result):
    fig, ax = plt.subplots(1, 1, figsize=(10, 5))
    ax.plot(np.arange(len(evals_result['training']['binary_error'])),
            evals_result['training']['binary_error'], label='Training')
    ax.plot(np.arange(len(evals_result['valid_1']['binary_error'])),
            evals_result['valid_1']['binary_error'], label='Validation')
    ax.set_title('Learning Curve')
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Binary Error')
    ax.legend()
    plt.show()

def plot_feature_importance(importances, feature_names):
    importance = pd.DataFrame({"Feature": feature_names,
                               "Importance": importances})
    importance.sort_values(by="Importance", ascending=False, inplace=True)
    plt.figure(figsize=(15, 30))
    sns.barplot(x="Importance", y="Feature", data=importance)
    plt.title("Feature Importance")
    plt.tight_layout()
    plt.show()

def train_and_evaluate(df, n_splits=5):
    features = df.drop('5m_target', axis=1)
    labels = df['5m_target']

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    feature_importances = []

    for train_index, test_index in kf.split(features):
        X_train, X_test = features.iloc[train_index], features.iloc[test_index]
        y_train, y_test = labels.iloc[train_index], labels.iloc[test_index]

        train_data = lgb.Dataset(X_train, label=y_train)
        test_data = lgb.Dataset(X_test, label=y_test)

        params = {
            'objective': 'binary',
            'metric': 'binary_error',
            'num_leaves': 31,
            'learning_rate': 0.05,
            'feature_fraction': 0.9
        }

        evals_result = {}

        model = lgb.train(
            params=params,
            train_set=train_data,
            valid_sets=[train_data, test_data],
            num_boost_round=10000,
            callbacks=[
                lgb.callback.early_stopping(10),
                lgb.callback.log_evaluation(period=100),
                lgb.callback.record_evaluation(evals_result)
            ],
        )

        y_pred = model.predict(X_test)
        y_pred = np.round(y_pred).astype(int)

        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
        print(f"Accuracy: {accuracy}")
        print(classification_report(y_test, y_pred))
        
        plot_learning_curve(evals_result)
        feature_importances.append(model.feature_importance())
    
    mean_accuracy = np.mean(accuracies)
    print(f"Mean accuracy: {mean_accuracy}")

    mean_importance = np.mean(feature_importances, axis=0)
    plot_feature_importance(mean_importance, features.columns)

    return model, evals_result

if __name__ == "__main__":
    file_names = [
        "data/BTCUSDT_1m_20210801_20221231.csv", 
        "data/BTCUSDT_5m_20210801_20221231.csv", 
        "data/BTCUSDT_15m_20210801_20221231.csv", 
        "data/BTCUSDT_30m_20210801_20221231.csv", 
        ]
    dfs = load_data(file_names)

    processed_dfs = []
    for df in dfs:
        prefix = df.columns[0].split('_')[0]
        processed_df = feature_engineering(df, prefix)
        processed_df = create_label(processed_df, prefix)
        # Resample to 1m timeframe
        df_resampled = processed_df.resample('1T').asfreq()
        # Forward-fill NaN values
        df_resampled = df_resampled.fillna(method='ffill')
        processed_dfs.append(df_resampled)

    combined_df = pd.concat(processed_dfs, axis=1).dropna()

    # add feature support and resistance
    combined_df = support_resistance(combined_df, "1m")
    combined_df = support_resistance(combined_df, "5m")
    combined_df = support_resistance(combined_df, "15m")
    combined_df = support_resistance(combined_df, "30m")
    combined_df = price_relation(combined_df, '1m', '5m')
    combined_df = price_relation(combined_df, '5m', '15m')
    combined_df = price_relation(combined_df, '5m', '30m')

    model, evals_result = train_and_evaluate(combined_df)

    model_path = os.path.join("model", "5m_model.pkl")
    with open(model_path, "wb") as f:
        pickle.dump(model, f)

    print(f"Model saved to {model_path}")
# Out:
#                       1m_open   1m_high    1m_low  1m_close  1m_volume
# 2021-08-02 17:00:00  39813.76  39833.24  39813.76  39833.24   0.001866  \
# 2021-08-02 17:01:00  39833.24  39841.57  39808.09  39808.09   0.002172
# 2021-08-02 17:02:00  39808.09  39808.09  39774.18  39785.72   0.015617
# 2021-08-02 17:03:00  39785.72  39855.71  39785.72  39855.71   0.002553
# 2021-08-02 17:04:00  39855.71  39880.66  39855.71  39880.66   0.036472
# ...                       ...       ...       ...       ...        ...
# 2022-02-01 02:26:00  38366.15  38421.61  38366.15  38395.84   0.997834
# 2022-02-01 02:27:00  38395.84  38404.44  38376.80  38384.41   0.523059
# 2022-02-01 02:28:00  38384.41  38384.41  38377.26  38380.68   0.363381
# 2022-02-01 02:29:00  38380.68  38380.68  38357.02  38361.11   0.388326
# 2022-02-01 02:30:00  38361.11  38366.52  38356.56  38357.20   0.728420
#
#                      1m_RSI_ST  1m_RSI_LOG    1m_MACD  1m_MACD_ST     1m_ATR
# 2021-08-02 17:00:00   0.001557    4.127626   2.005121    0.000050  26.605512  \
# 2021-08-02 17:01:00   0.001416    4.031831   4.525034    0.000114  27.096547
# 2021-08-02 17:02:00   0.001303    3.947948   4.663256    0.000117  27.583222
# 2021-08-02 17:03:00   0.001558    4.128796  10.301655    0.000258  30.612278
# 2021-08-02 17:04:00   0.001629    4.173945  16.592119    0.000416  30.207829
# ...                        ...         ...        ...         ...        ...
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.080061 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 29076
# [LightGBM] [Info] Number of data points in the train set: 210120, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495460 -> initscore=-0.018162
# [LightGBM] [Info] Start training from score -0.018162
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.13528	valid_1's binary_error: 0.14125
# [200]	training's binary_error: 0.111151	valid_1's binary_error: 0.120196
# [300]	training's binary_error: 0.097392	valid_1's binary_error: 0.108488
# [400]	training's binary_error: 0.0864744	valid_1's binary_error: 0.100131
# [500]	training's binary_error: 0.0772321	valid_1's binary_error: 0.0928785
# [600]	training's binary_error: 0.0691986	valid_1's binary_error: 0.0867678
# [700]	training's binary_error: 0.0618694	valid_1's binary_error: 0.081133
# [800]	training's binary_error: 0.0557967	valid_1's binary_error: 0.0761074
# [900]	training's binary_error: 0.049505	valid_1's binary_error: 0.0707582
# [1000]	training's binary_error: 0.0440843	valid_1's binary_error: 0.0661133
# [1100]	training's binary_error: 0.0388254	valid_1's binary_error: 0.0617921
# [1200]	training's binary_error: 0.0341709	valid_1's binary_error: 0.0579848
# [1300]	training's binary_error: 0.0303826	valid_1's binary_error: 0.054425
# [1400]	training's binary_error: 0.0265991	valid_1's binary_error: 0.0505416
# [1500]	training's binary_error: 0.023063	valid_1's binary_error: 0.0467724
# [1600]	training's binary_error: 0.0198553	valid_1's binary_error: 0.0436885
# [1700]	training's binary_error: 0.0174329	valid_1's binary_error: 0.0404142
# [1800]	training's binary_error: 0.0150057	valid_1's binary_error: 0.0375588
# Early stopping, best iteration is:
# [1821]	training's binary_error: 0.0145583	valid_1's binary_error: 0.0369306
# Accuracy: 0.9630694256724601
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     26496
#          1.0       0.96      0.96      0.96     26035
#
#     accuracy                           0.96     52531
#    macro avg       0.96      0.96      0.96     52531
# weighted avg       0.96      0.96      0.96     52531
# [LightGBM] [Info] Number of positive: 104054, number of negative: 106067
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019051 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 29076
# [LightGBM] [Info] Number of data points in the train set: 210121, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495210 -> initscore=-0.019161
# [LightGBM] [Info] Start training from score -0.019161
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.135498	valid_1's binary_error: 0.139615
# [200]	training's binary_error: 0.111464	valid_1's binary_error: 0.118561
# [300]	training's binary_error: 0.0976675	valid_1's binary_error: 0.106472
# [400]	training's binary_error: 0.0869023	valid_1's binary_error: 0.0986294
# [500]	training's binary_error: 0.0779123	valid_1's binary_error: 0.0913002
# [600]	training's binary_error: 0.0695456	valid_1's binary_error: 0.0841995
# [700]	training's binary_error: 0.0621213	valid_1's binary_error: 0.0788883
# Early stopping, best iteration is:
# [702]	training's binary_error: 0.06195	valid_1's binary_error: 0.0786789
# Accuracy: 0.9213211498191509
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.92      0.92     26443
#          1.0       0.92      0.92      0.92     26087
#
#     accuracy                           0.92     52530
#    macro avg       0.92      0.92      0.92     52530
# weighted avg       0.92      0.92      0.92     52530
# [LightGBM] [Info] Number of positive: 104068, number of negative: 106053
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017979 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 29076
# [LightGBM] [Info] Number of data points in the train set: 210121, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495277 -> initscore=-0.018894
# [LightGBM] [Info] Start training from score -0.018894
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.135479	valid_1's binary_error: 0.1423
# [200]	training's binary_error: 0.111512	valid_1's binary_error: 0.119018
# [300]	training's binary_error: 0.0971393	valid_1's binary_error: 0.107424
# [400]	training's binary_error: 0.0863693	valid_1's binary_error: 0.0985151
# [500]	training's binary_error: 0.0776886	valid_1's binary_error: 0.0923472
# [600]	training's binary_error: 0.0699264	valid_1's binary_error: 0.085989
# [700]	training's binary_error: 0.0625497	valid_1's binary_error: 0.0804873
# [800]	training's binary_error: 0.0556299	valid_1's binary_error: 0.0759566
# [900]	training's binary_error: 0.0493668	valid_1's binary_error: 0.0708357
# [1000]	training's binary_error: 0.0439651	valid_1's binary_error: 0.0665144
# [1100]	training's binary_error: 0.0383922	valid_1's binary_error: 0.0616981
# [1200]	training's binary_error: 0.0339138	valid_1's binary_error: 0.056996
# [1300]	training's binary_error: 0.0297686	valid_1's binary_error: 0.0536836
# [1400]	training's binary_error: 0.025985	valid_1's binary_error: 0.0503331
# [1500]	training's binary_error: 0.0227631	valid_1's binary_error: 0.0469446
# [1600]	training's binary_error: 0.0200741	valid_1's binary_error: 0.0443556
# Early stopping, best iteration is:
# [1682]	training's binary_error: 0.0178945	valid_1's binary_error: 0.0415001
# Accuracy: 0.9584999048162954
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     26457
#          1.0       0.96      0.96      0.96     26073
#
#     accuracy                           0.96     52530
#    macro avg       0.96      0.96      0.96     52530
# weighted avg       0.96      0.96      0.96     52530
# [LightGBM] [Info] Number of positive: 104068, number of negative: 106053
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086067 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 29076
# [LightGBM] [Info] Number of data points in the train set: 210121, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495277 -> initscore=-0.018894
# [LightGBM] [Info] Start training from score -0.018894
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.135998	valid_1's binary_error: 0.141119
# [200]	training's binary_error: 0.111859	valid_1's binary_error: 0.119513
# [300]	training's binary_error: 0.0975676	valid_1's binary_error: 0.106872
# [400]	training's binary_error: 0.0869404	valid_1's binary_error: 0.0991243
# [500]	training's binary_error: 0.0777838	valid_1's binary_error: 0.0925757
# [600]	training's binary_error: 0.0694362	valid_1's binary_error: 0.0858367
# [700]	training's binary_error: 0.0619738	valid_1's binary_error: 0.0800495
# [800]	training's binary_error: 0.0552777	valid_1's binary_error: 0.074605
# [900]	training's binary_error: 0.0490908	valid_1's binary_error: 0.0699791
# [1000]	training's binary_error: 0.043494	valid_1's binary_error: 0.0652389
# [1100]	training's binary_error: 0.0387015	valid_1's binary_error: 0.0612222
# [1200]	training's binary_error: 0.0341375	valid_1's binary_error: 0.057015
# [1300]	training's binary_error: 0.0299351	valid_1's binary_error: 0.0524462
# [1400]	training's binary_error: 0.0265609	valid_1's binary_error: 0.0488292
# [1500]	training's binary_error: 0.0230296	valid_1's binary_error: 0.045574
# [1600]	training's binary_error: 0.0201217	valid_1's binary_error: 0.0425281
# [1700]	training's binary_error: 0.0175518	valid_1's binary_error: 0.0394632
# [1800]	training's binary_error: 0.0151532	valid_1's binary_error: 0.0370265
# [1900]	training's binary_error: 0.013102	valid_1's binary_error: 0.0343232
# [2000]	training's binary_error: 0.0111317	valid_1's binary_error: 0.0319817
# [2100]	training's binary_error: 0.00947549	valid_1's binary_error: 0.030059
# [2200]	training's binary_error: 0.00826667	valid_1's binary_error: 0.0281744
# [2300]	training's binary_error: 0.00700073	valid_1's binary_error: 0.0260803
# Early stopping, best iteration is:
# [2342]	training's binary_error: 0.00650578	valid_1's binary_error: 0.0249952
# Accuracy: 0.9750047591852274
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.98     26457
#          1.0       0.98      0.97      0.97     26073
#
#     accuracy                           0.98     52530
#    macro avg       0.98      0.98      0.98     52530
# weighted avg       0.98      0.98      0.98     52530
# [LightGBM] [Info] Number of positive: 104268, number of negative: 105853
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.075433 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 29076
# [LightGBM] [Info] Number of data points in the train set: 210121, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.496228 -> initscore=-0.015087
# [LightGBM] [Info] Start training from score -0.015087
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.135769	valid_1's binary_error: 0.138302
# [200]	training's binary_error: 0.111279	valid_1's binary_error: 0.116943
# [300]	training's binary_error: 0.0976009	valid_1's binary_error: 0.105673
# [400]	training's binary_error: 0.0868214	valid_1's binary_error: 0.0969351
# [500]	training's binary_error: 0.0776124	valid_1's binary_error: 0.0907291
# [600]	training's binary_error: 0.0696551	valid_1's binary_error: 0.0843518
# [700]	training's binary_error: 0.0624735	valid_1's binary_error: 0.0782029
# [800]	training's binary_error: 0.0558345	valid_1's binary_error: 0.0733866
# [900]	training's binary_error: 0.0496	valid_1's binary_error: 0.0683038
# [1000]	training's binary_error: 0.04387	valid_1's binary_error: 0.063202
# [1100]	training's binary_error: 0.0388252	valid_1's binary_error: 0.0589758
# [1200]	training's binary_error: 0.0340233	valid_1's binary_error: 0.0552065
# [1300]	training's binary_error: 0.0298209	valid_1's binary_error: 0.0509042
# [1400]	training's binary_error: 0.0262373	valid_1's binary_error: 0.0470779
# [1500]	training's binary_error: 0.0232104	valid_1's binary_error: 0.0439178
# [1600]	training's binary_error: 0.0200551	valid_1's binary_error: 0.0408719
# [1700]	training's binary_error: 0.0175946	valid_1's binary_error: 0.0377879
# [1800]	training's binary_error: 0.0149818	valid_1's binary_error: 0.0354464
# [1900]	training's binary_error: 0.0128355	valid_1's binary_error: 0.0328384
# Early stopping, best iteration is:
# [1966]	training's binary_error: 0.0114696	valid_1's binary_error: 0.0309157
# Accuracy: 0.9690843327622312
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     26657
#          1.0       0.97      0.97      0.97     25873
#
#     accuracy                           0.97     52530
#    macro avg       0.97      0.97      0.97     52530
# weighted avg       0.97      0.97      0.97     52530
# Mean accuracy: 0.9573959144510731
# Model saved to model/5m_model.pkl
