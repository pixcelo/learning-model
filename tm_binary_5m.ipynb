# %%
import os
import pandas as pd
import numpy as np
import talib
import lightgbm as lgb
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split, KFold
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from datetime import datetime, time, timedelta

pd.set_option('display.max_columns', None)

def load_data(file_names):
    dfs = []
    for file_name in file_names:
        prefix = file_name.split('_')[1]
        df = pd.read_csv(file_name, index_col=f"{prefix}_timestamp")
        df.index = pd.to_datetime(df.index, unit="ms")
        dfs.append(df)
    return dfs

def feature_engineering(df, prefix):
    open = df[f'{prefix}_open'].values
    high = df[f'{prefix}_high'].values
    low = df[f'{prefix}_low'].values
    close = df[f'{prefix}_close'].values
    volume = df[f'{prefix}_volume'].values
    hilo = (high + low) / 2

    df[f'{prefix}_RSI_ST'] = talib.RSI(close)/close
    df[f'{prefix}_RSI_LOG'] = log_transform_feature(talib.RSI(close))
    df[f'{prefix}_MACD'], _, _ = talib.MACD(close)
    df[f'{prefix}_MACD_ST'], _, _ = talib.MACD(close)/close
    df[f'{prefix}_ATR'] = talib.ATR(high, low, close)
    df[f'{prefix}_ADX'] = talib.ADX(high, low, close, timeperiod=14)
    df[f'{prefix}_ADXR'] = talib.ADXR(high, low, close, timeperiod=14)
    
    df[f'{prefix}_SMA20'] = talib.SMA(close, timeperiod=20)
    df[f'{prefix}_SMA50'] = talib.SMA(close, timeperiod=50)
    df[f'{prefix}_SMA100'] = talib.SMA(close, timeperiod=100)
    
    df[f'{prefix}_BB_UPPER'], df[f'{prefix}_BB_MIDDLE'], df[f'{prefix}_BB_LOWER'] = talib.BBANDS(close)
    df[f'{prefix}_BBANDS_upperband'] = (df[f'{prefix}_BB_UPPER'] - hilo) / close
    df[f'{prefix}_BBANDS_middleband'] = (df[f'{prefix}_BB_MIDDLE'] - hilo) / close
    df[f'{prefix}_BBANDS_lowerband'] = (df[f'{prefix}_BB_LOWER'] - hilo) / close
    df[f'{prefix}_STOCH_K'], df[f'{prefix}_STOCH_D'] = talib.STOCH(high, low, close)/close
    df[f'{prefix}_MON'] = talib.MOM(close, timeperiod=5)
    df[f'{prefix}_OBV'] = talib.OBV(close, volume)

    df = df.fillna(method='ffill')

    return df

def log_transform_feature(X):
    X[X <= 0] = np.finfo(float).eps
    return np.log(X)

def support_resistance(df, prefix, window=20):
    high = df[f'{prefix}_high']
    low = df[f'{prefix}_low']
    close = df[f'{prefix}_close']
    df[f'{prefix}_support'] = low.rolling(window=window, min_periods=1).min()
    df[f'{prefix}_resistance'] = high.rolling(window=window, min_periods=1).max()
    return df

def price_relation(df, short_prefix, long_prefix):
    short_close = df[f'{short_prefix}_close']
    long_support = df[f'{long_prefix}_support']
    long_resistance = df[f'{long_prefix}_resistance']
    df[f'{short_prefix}_close_to_{long_prefix}_support'] = (short_close - long_support) / long_support
    df[f'{short_prefix}_close_to_{long_prefix}_resistance'] = (short_close - long_resistance) / long_resistance
    return df

def calculate_high_close_comparison(df, prefix):
    high = df[f'{prefix}_high'].values
    close = df[f'{prefix}_close'].values
    higher_high = np.zeros(len(high), dtype=int)
    higher_close = np.zeros(len(close), dtype=int)
    higher_high[1:] = high[1:] > high[:-1]
    higher_close[1:] = close[1:] > close[:-1]
    high_close_comparison = higher_high & higher_close
    return high_close_comparison

def detect_double_top_bottom(df, prefix, window=5, tolerance=0.03):
    double_top = np.zeros(len(df), dtype=int)
    double_bottom = np.zeros(len(df), dtype=int)

    close = df[f'{prefix}_close'].values
    close_ext = np.pad(close, (window, window), mode='edge')

    for i in range(window, len(df) - window):
        considered_range = close_ext[i:i + window * 2 + 1]
        max_index = np.argmax(considered_range)
        min_index = np.argmin(considered_range)

        if max_index == window:
            max_left = np.max(considered_range[:window])
            max_right = np.max(considered_range[window + 1:])
            max_avg = (max_left + max_right) / 2

            if np.abs(considered_range[window] - max_avg) / considered_range[window] <= tolerance:
                double_top[i] = 1

        if min_index == window:
            min_left = np.min(considered_range[:window])
            min_right = np.min(considered_range[window + 1:])
            min_avg = (min_left + min_right) / 2

            if np.abs(considered_range[window] - min_avg) / considered_range[window] <= tolerance:
                double_bottom[i] = 1

    return double_top, double_bottom

def create_label(df, prefix, lookbehind=1):
    df[f'{prefix}_target'] = (df[f'{prefix}_close'] > df[f'{prefix}_close'].shift(lookbehind)).astype(int)
    df = df.fillna(method='ffill')
    return df

def plot_learning_curve(evals_result):
    fig, ax = plt.subplots(1, 1, figsize=(10, 5))
    ax.plot(np.arange(len(evals_result['training']['binary_error'])),
            evals_result['training']['binary_error'], label='Training')
    ax.plot(np.arange(len(evals_result['valid_1']['binary_error'])),
            evals_result['valid_1']['binary_error'], label='Validation')
    ax.set_title('Learning Curve')
    ax.set_xlabel('Iteration')
    ax.set_ylabel('Binary Error')
    ax.legend()
    plt.show()

def plot_feature_importance(importances, feature_names):
    importance = pd.DataFrame({"Feature": feature_names,
                               "Importance": importances})
    importance.sort_values(by="Importance", ascending=False, inplace=True)
    plt.figure(figsize=(15, 30))
    sns.barplot(x="Importance", y="Feature", data=importance)
    plt.title("Feature Importance")
    plt.tight_layout()
    plt.show()

def train_and_evaluate(df, n_splits=5):
    features = df.drop('5m_target', axis=1)
    labels = df['5m_target']

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []
    feature_importances = []

    for train_index, test_index in kf.split(features):
        X_train, X_test = features.iloc[train_index], features.iloc[test_index]
        y_train, y_test = labels.iloc[train_index], labels.iloc[test_index]

        train_data = lgb.Dataset(X_train, label=y_train)
        test_data = lgb.Dataset(X_test, label=y_test)

        params = {
            'objective': 'binary',
            'metric': 'binary_error',
            'num_leaves': 31,
            'learning_rate': 0.05,
            'feature_fraction': 0.9
        }

        evals_result = {}

        model = lgb.train(
            params=params,
            train_set=train_data,
            valid_sets=[train_data, test_data],
            num_boost_round=10000,
            callbacks=[
                lgb.callback.early_stopping(10),
                lgb.callback.log_evaluation(period=100),
                lgb.callback.record_evaluation(evals_result)
            ],
        )

        y_pred = model.predict(X_test)
        y_pred = np.round(y_pred).astype(int)

        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)
        print(f"Accuracy: {accuracy}")
        print(classification_report(y_test, y_pred))
        
        plot_learning_curve(evals_result)
        feature_importances.append(model.feature_importance())
    
    mean_accuracy = np.mean(accuracies)
    print(f"Mean accuracy: {mean_accuracy}")

    mean_importance = np.mean(feature_importances, axis=0)
    plot_feature_importance(mean_importance, features.columns)

    return model, evals_result

if __name__ == "__main__":
    file_names = [
        "data/BTCUSDT_1m_20210801_20221231.csv", 
        "data/BTCUSDT_5m_20210801_20221231.csv", 
        "data/BTCUSDT_15m_20210801_20221231.csv", 
        "data/BTCUSDT_30m_20210801_20221231.csv", 
        ]
    dfs = load_data(file_names)

    processed_dfs = []
    for df in dfs:
        prefix = df.columns[0].split('_')[0]
        processed_df = feature_engineering(df, prefix)


        processed_df = create_label(processed_df, prefix)
        # Resample to 1m timeframe
        df_resampled = processed_df.resample('1T').asfreq()
        # Forward-fill NaN values
        df_resampled = df_resampled.fillna(method='ffill')
        processed_dfs.append(df_resampled)

    combined_df = pd.concat(processed_dfs, axis=1).fillna(0)

    # add feature support and resistance
    combined_df = support_resistance(combined_df, "1m")
    combined_df = support_resistance(combined_df, "5m")
    combined_df = support_resistance(combined_df, "15m")
    combined_df = support_resistance(combined_df, "30m")
    combined_df = price_relation(combined_df, '1m', '5m')
    combined_df = price_relation(combined_df, '5m', '15m')
    combined_df = price_relation(combined_df, '5m', '30m')

    model, evals_result = train_and_evaluate(combined_df)

    model_path = os.path.join("model", "5m_model.pkl")
    with open(model_path, "wb") as f:
        pickle.dump(model, f)

    print(f"Model saved to {model_path}")
# Out:
# [LightGBM] [Info] Number of positive: 145428, number of negative: 453612
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.096752 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28911
# [LightGBM] [Info] Number of data points in the train set: 599040, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242768 -> initscore=-1.137561
# [LightGBM] [Info] Start training from score -1.137561
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.0721688	valid_1's binary_error: 0.0736111
# [200]	training's binary_error: 0.0601946	valid_1's binary_error: 0.0630475
# [300]	training's binary_error: 0.0536024	valid_1's binary_error: 0.0572382
# [400]	training's binary_error: 0.0488699	valid_1's binary_error: 0.0532252
# [500]	training's binary_error: 0.0449636	valid_1's binary_error: 0.050394
# [600]	training's binary_error: 0.0417034	valid_1's binary_error: 0.0476562
# [700]	training's binary_error: 0.0386619	valid_1's binary_error: 0.0452123
# [800]	training's binary_error: 0.0358657	valid_1's binary_error: 0.0432559
# [900]	training's binary_error: 0.0332732	valid_1's binary_error: 0.0412326
# [1000]	training's binary_error: 0.0307275	valid_1's binary_error: 0.0392361
# Early stopping, best iteration is:
# [1029]	training's binary_error: 0.0300614	valid_1's binary_error: 0.038742
# Accuracy: 0.9612580128205128
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97    113388
#          1.0       0.92      0.92      0.92     36372
#
#     accuracy                           0.96    149760
#    macro avg       0.95      0.95      0.95    149760
# weighted avg       0.96      0.96      0.96    149760
# [LightGBM] [Info] Number of positive: 145531, number of negative: 453509
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.095943 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28909
# [LightGBM] [Info] Number of data points in the train set: 599040, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242940 -> initscore=-1.136626
# [LightGBM] [Info] Start training from score -1.136626
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.0717498	valid_1's binary_error: 0.0745259
# [200]	training's binary_error: 0.0602414	valid_1's binary_error: 0.0635417
# [300]	training's binary_error: 0.0538228	valid_1's binary_error: 0.0576923
# [400]	training's binary_error: 0.049152	valid_1's binary_error: 0.0540999
# [500]	training's binary_error: 0.0454711	valid_1's binary_error: 0.0510617
# [600]	training's binary_error: 0.042074	valid_1's binary_error: 0.0481637
# [700]	training's binary_error: 0.0389273	valid_1's binary_error: 0.0458133
# [800]	training's binary_error: 0.0360761	valid_1's binary_error: 0.0436632
# [900]	training's binary_error: 0.0334435	valid_1's binary_error: 0.0416266
# [1000]	training's binary_error: 0.0309796	valid_1's binary_error: 0.0395433
# [1100]	training's binary_error: 0.0286892	valid_1's binary_error: 0.0377738
# [1200]	training's binary_error: 0.0265692	valid_1's binary_error: 0.0361311
# [1300]	training's binary_error: 0.0244358	valid_1's binary_error: 0.0343015
# [1400]	training's binary_error: 0.022501	valid_1's binary_error: 0.0326856
# [1500]	training's binary_error: 0.0207432	valid_1's binary_error: 0.03125
# [1600]	training's binary_error: 0.018967	valid_1's binary_error: 0.0297543
# [1700]	training's binary_error: 0.0173995	valid_1's binary_error: 0.0283721
# [1800]	training's binary_error: 0.0158787	valid_1's binary_error: 0.0269965
# [1900]	training's binary_error: 0.0144581	valid_1's binary_error: 0.0257479
# [2000]	training's binary_error: 0.0130726	valid_1's binary_error: 0.0244124
# [2100]	training's binary_error: 0.011844	valid_1's binary_error: 0.0232772
# [2200]	training's binary_error: 0.0107589	valid_1's binary_error: 0.0220419
# [2300]	training's binary_error: 0.00980736	valid_1's binary_error: 0.0210203
# [2400]	training's binary_error: 0.00892595	valid_1's binary_error: 0.0199452
# [2500]	training's binary_error: 0.00801115	valid_1's binary_error: 0.0188568
# Early stopping, best iteration is:
# [2537]	training's binary_error: 0.00774406	valid_1's binary_error: 0.0185697
# Accuracy: 0.9814302884615385
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99    113491
#          1.0       0.96      0.96      0.96     36269
#
#     accuracy                           0.98    149760
#    macro avg       0.97      0.97      0.97    149760
# weighted avg       0.98      0.98      0.98    149760
# [LightGBM] [Info] Number of positive: 145467, number of negative: 453573
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.088468 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28914
# [LightGBM] [Info] Number of data points in the train set: 599040, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242834 -> initscore=-1.137207
# [LightGBM] [Info] Start training from score -1.137207
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.0726412	valid_1's binary_error: 0.072723
# [200]	training's binary_error: 0.060425	valid_1's binary_error: 0.061899
# [300]	training's binary_error: 0.0535607	valid_1's binary_error: 0.0562233
# [400]	training's binary_error: 0.0490802	valid_1's binary_error: 0.0526776
# [500]	training's binary_error: 0.0453592	valid_1's binary_error: 0.0495793
# [600]	training's binary_error: 0.0420289	valid_1's binary_error: 0.0471755
# [700]	training's binary_error: 0.0389206	valid_1's binary_error: 0.0447583
# [800]	training's binary_error: 0.0360844	valid_1's binary_error: 0.0423945
# [900]	training's binary_error: 0.0334769	valid_1's binary_error: 0.0402377
# [1000]	training's binary_error: 0.0308744	valid_1's binary_error: 0.0382212
# [1100]	training's binary_error: 0.0285741	valid_1's binary_error: 0.0364183
# [1200]	training's binary_error: 0.0264156	valid_1's binary_error: 0.034809
# [1300]	training's binary_error: 0.0242672	valid_1's binary_error: 0.0329661
# [1400]	training's binary_error: 0.0224192	valid_1's binary_error: 0.0314236
# [1500]	training's binary_error: 0.0205596	valid_1's binary_error: 0.0299279
# [1600]	training's binary_error: 0.0188936	valid_1's binary_error: 0.0286124
# [1700]	training's binary_error: 0.0172309	valid_1's binary_error: 0.02711
# [1800]	training's binary_error: 0.0157969	valid_1's binary_error: 0.0258881
# [1900]	training's binary_error: 0.0144565	valid_1's binary_error: 0.0247329
# [2000]	training's binary_error: 0.0130993	valid_1's binary_error: 0.0236445
# [2100]	training's binary_error: 0.0118823	valid_1's binary_error: 0.0224559
# [2200]	training's binary_error: 0.0107839	valid_1's binary_error: 0.0213542
# [2300]	training's binary_error: 0.00980235	valid_1's binary_error: 0.0203259
# [2400]	training's binary_error: 0.0089393	valid_1's binary_error: 0.019391
# Early stopping, best iteration is:
# [2479]	training's binary_error: 0.00829661	valid_1's binary_error: 0.0186632
# Accuracy: 0.9813368055555556
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99    113427
#          1.0       0.96      0.96      0.96     36333
#
#     accuracy                           0.98    149760
#    macro avg       0.97      0.97      0.97    149760
# weighted avg       0.98      0.98      0.98    149760
# [LightGBM] [Info] Number of positive: 145513, number of negative: 453527
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.096267 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28913
# [LightGBM] [Info] Number of data points in the train set: 599040, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242910 -> initscore=-1.136789
# [LightGBM] [Info] Start training from score -1.136789
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.0720853	valid_1's binary_error: 0.0731103
# [200]	training's binary_error: 0.0603532	valid_1's binary_error: 0.0627137
# [300]	training's binary_error: 0.0537226	valid_1's binary_error: 0.0570446
# [400]	training's binary_error: 0.0490401	valid_1's binary_error: 0.0530783
# [500]	training's binary_error: 0.0454344	valid_1's binary_error: 0.0498064
# [600]	training's binary_error: 0.0419404	valid_1's binary_error: 0.0472089
# [700]	training's binary_error: 0.038757	valid_1's binary_error: 0.044765
# [800]	training's binary_error: 0.0359542	valid_1's binary_error: 0.0427818
# [900]	training's binary_error: 0.0333216	valid_1's binary_error: 0.0407585
# [1000]	training's binary_error: 0.0307225	valid_1's binary_error: 0.0388154
# [1100]	training's binary_error: 0.0284572	valid_1's binary_error: 0.0369925
# [1200]	training's binary_error: 0.0261869	valid_1's binary_error: 0.0352097
# [1300]	training's binary_error: 0.0241303	valid_1's binary_error: 0.0334535
# [1400]	training's binary_error: 0.0221972	valid_1's binary_error: 0.0319311
# [1500]	training's binary_error: 0.0203626	valid_1's binary_error: 0.0304554
# [1600]	training's binary_error: 0.0186916	valid_1's binary_error: 0.0289597
# [1700]	training's binary_error: 0.0170106	valid_1's binary_error: 0.0276643
# [1800]	training's binary_error: 0.0155349	valid_1's binary_error: 0.0263021
# [1900]	training's binary_error: 0.0142278	valid_1's binary_error: 0.0251202
# Early stopping, best iteration is:
# [1942]	training's binary_error: 0.0137153	valid_1's binary_error: 0.0243924
# Accuracy: 0.9756076388888889
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98    113473
#          1.0       0.95      0.95      0.95     36287
#
#     accuracy                           0.98    149760
#    macro avg       0.97      0.97      0.97    149760
# weighted avg       0.98      0.98      0.98    149760
# [LightGBM] [Info] Number of positive: 145261, number of negative: 453779
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.114545 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28916
# [LightGBM] [Info] Number of data points in the train set: 599040, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242490 -> initscore=-1.139078
# [LightGBM] [Info] Start training from score -1.139078
# Training until validation scores don't improve for 10 rounds
# [100]	training's binary_error: 0.0719401	valid_1's binary_error: 0.0753673
# [200]	training's binary_error: 0.0601162	valid_1's binary_error: 0.0639156
# [300]	training's binary_error: 0.0536709	valid_1's binary_error: 0.0579193
# [400]	training's binary_error: 0.0490034	valid_1's binary_error: 0.0536859
# [500]	training's binary_error: 0.0451239	valid_1's binary_error: 0.0508146
# [600]	training's binary_error: 0.0418436	valid_1's binary_error: 0.0483507
# [700]	training's binary_error: 0.0386569	valid_1's binary_error: 0.0459468
# [800]	training's binary_error: 0.0359024	valid_1's binary_error: 0.04375
# [900]	training's binary_error: 0.0331731	valid_1's binary_error: 0.0418803
# [1000]	training's binary_error: 0.0307709	valid_1's binary_error: 0.039777
# [1100]	training's binary_error: 0.0284689	valid_1's binary_error: 0.0376269
# [1200]	training's binary_error: 0.0261385	valid_1's binary_error: 0.035844
# [1300]	training's binary_error: 0.0239767	valid_1's binary_error: 0.0340745
# [1400]	training's binary_error: 0.0219885	valid_1's binary_error: 0.0325921
# [1500]	training's binary_error: 0.0201639	valid_1's binary_error: 0.0309762
# [1600]	training's binary_error: 0.0185163	valid_1's binary_error: 0.029614
# [1700]	training's binary_error: 0.0169254	valid_1's binary_error: 0.0282986
# [1800]	training's binary_error: 0.0154147	valid_1's binary_error: 0.0268897
# [1900]	training's binary_error: 0.0141526	valid_1's binary_error: 0.0255743
# [2000]	training's binary_error: 0.012924	valid_1's binary_error: 0.0243122
# [2100]	training's binary_error: 0.0117955	valid_1's binary_error: 0.0230435
# [2200]	training's binary_error: 0.0107338	valid_1's binary_error: 0.0219818
# [2300]	training's binary_error: 0.00974559	valid_1's binary_error: 0.0208133
# [2400]	training's binary_error: 0.00873564	valid_1's binary_error: 0.0197449
# Early stopping, best iteration is:
# [2449]	training's binary_error: 0.00830829	valid_1's binary_error: 0.0193443
# Accuracy: 0.9806557158119659
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99    113221
#          1.0       0.96      0.96      0.96     36539
#
#     accuracy                           0.98    149760
#    macro avg       0.97      0.97      0.97    149760
# weighted avg       0.98      0.98      0.98    149760
# Mean accuracy: 0.9760576923076923
# Model saved to model/5m_model.pkl
